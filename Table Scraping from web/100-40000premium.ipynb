# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/100-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('100prize.csv',          # Export pandas DataFrame as CSV
            header = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Draw No.   38 non-null     int64
#  1   1st        38 non-null     int64
#  2   2nd        38 non-null     int64
#  3   2nd.1      38 non-null     int64
#  4   2nd.2      38 non-null     int64
#  5   City       38 non-null     object
#  6   Date       38 non-null     object
#  7   Full List  38 non-null     object
# dtypes: int64(5), object(3)
# memory usage: 2.5+ KB

# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/200-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('200prize.csv',          # Export pandas DataFrame as CSV
            header = True)

# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/750-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('750prize.csv',          # Export pandas DataFrame as CSV
            header = True)

# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/1500-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('1500prize.csv',          # Export pandas DataFrame as CSV
            header = True)

# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/7500-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('7500prize.csv',          # Export pandas DataFrame as CSV
            header = True)

# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/15000-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('15000prize.csv',          # Export pandas DataFrame as CSV
            header = True)

# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/25000-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('25000prize.csv',          # Export pandas DataFrame as CSV
            header = True)

# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/25000-premium-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('25000_premium_prize.csv',          # Export pandas DataFrame as CSV
            header = True)

# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/40000-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('40000prize.csv',          # Export pandas DataFrame as CSV
            header = True)

# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io
url = f"https://www.prizeinfo.net/40000-premium-prize-bond-first-second-record/"
session = HTMLSession()
response = session.get(url)
soup = bs(response.html.html, 'html.parser')
      
table = soup.find('table', attrs={'class':'table'})
data = pd.read_html(str(table))
dfs = pd.concat(data)
# replace NaN with empty string
df = dfs.replace(np.nan, '')
df.to_csv('40000_premium_prize.csv',          # Export pandas DataFrame as CSV
            header = True)
