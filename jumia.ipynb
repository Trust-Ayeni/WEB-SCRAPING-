# %%
import requests
import requests_html
from requests_html import HTMLSession
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import io

# %%
product_name = []
product_price = []
product_rating = []
product_img_url = []
old_price = []
product_sku = []

# %%
page = 1
while page != 51:
      url = f"https://www.jumia.com.ng/catalog/?q=laptop&page={page}"
      session = HTMLSession()
      response = session.get(url)
      soup = bs(response.html.html, 'html.parser')
      
      for tag in soup.findAll(attrs={'class':'prd _fb col c-prd'}):
        
        # finding the product name
        div1 = tag.find('div', attrs={'class':'info'})
        name = div1.find('h3', attrs={'class':'name'})
          
        # finding the product price (former price and new price)
        nprice = div1.find('div', attrs={'class':'prc'})
        fprice = div1.find('div', attrs={'class':'old'})
            
        # finding the product SKU
        skus = tag.find('a', attrs={'class':'core'}).get('data-id')
          
        # finding the rating
        rating = div1.find('div', attrs={'class':'stars _s'})
        
        # finding the image url
        img_url = tag.find('img')['data-src']
          
        product_name.append(name.text)
        product_price.append(nprice.text)
        old_price.append(fprice)  
        product_rating.append(rating)
        product_img_url.append(img_url)
        product_sku.append(skus)
      
      page += 1

# %%
print(old_price[0], product_name[0], product_price[0])
# Out:
# <div class="old">₦ 190,000</div> Lenovo Ideapad Intel Celeron 1TB HDD 8GB RAM Win 10+ 32GB Flash ₦ 169,990

# %%
product_list = pd.DataFrame({'product_name': product_name,
                             'product_price': product_price,
                             'product_rating': product_rating,
                             'product_img_url': product_img_url,
                             'product_SKU': product_sku,
                             'old_price': old_price})

# %%
product_list.product_img_url
# Out:
# 0       https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 1       https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 2       https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 3       https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 4       https://ng.jumia.is/unsafe/fit-in/300x300/filt...
#                               ...
# 1995    https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 1996    https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 1997    https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 1998    https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# 1999    https://ng.jumia.is/unsafe/fit-in/300x300/filt...
# Name: product_img_url, Length: 2000, dtype: object

# %%
product_list.to_csv('products.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Read DataFrame

# %%
data = pd.read_csv('products.csv')

# %%
data.duplicated().sum()
# Out:
# 0

# %%
df = data.copy()                               # Create duplicate of data
df = df.replace(r'^s*$', float('NaN'), regex = True)  # Replace blanks by NaN
df
# Out:
#                                            product_name product_price  \
# 0     Lenovo Ideapad Intel Celeron 1TB HDD 8GB RAM W...     ₦ 169,990
# 1     Hp 15 DW1207NIA Intel Celeron N4020,4GB/500GB ...     ₦ 156,760
# 2     Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 3     Infinix INBook X1 Pro Intel Core I3 256GB SSD ...     ₦ 210,500
# 4     Lenovo INTEL® CELERON® Lenovo Ideapad 4GB RAM ...     ₦ 130,910
# ...                                                 ...           ...
# 1995  DELL Inspiron 3501-7897BLK Core™ I7-1165G7 512...     ₦ 550,000
# 1996  Hp Pavilion 14 X360 11th Gen-Core-i3 16GB/512 ...     ₦ 377,000
# 1997  Hp Pavilion 15 Intel Pentium Quad Core 8GB RAM...     ₦ 220,000
# 1998  Lenovo Ideapad  4GBRAM - 1TB HDD Intel Celeron...     ₦ 138,989
# 1999  Hp Stream 11 Intel Celeron (4GB,32GB SSD+  32G...     ₦ 125,500
#
#                                          product_rating  \
# 0     <div class="stars _s">4.3 out of 5<div class="...
# 1     <div class="stars _s">4 out of 5<div class="in...
# 2     <div class="stars _s">3.9 out of 5<div class="...
# 3     <div class="stars _s">4.5 out of 5<div class="...
# 4     <div class="stars _s">4.2 out of 5<div class="...
# ...                                                 ...
# 1995                                                NaN
# 1996                                                NaN
# 1997                                                NaN
# 1998                                                NaN
# 1999                                                NaN
#
#                                         product_img_url          product_SKU  \
# 0     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0S218XNAFAMZ
# 1     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL2A5NICNAFAMZ
# 2     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1MUH3JNAFAMZ
# 3     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  IN717CL1WDKK4NAFAMZ
# 4     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL2UIZLFNAFAMZ
# ...                                                 ...                  ...
# 1995  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  DE168CL1VMFPRNAFAMZ
# 1996  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0GE0XVNAFAMZ
# 1997  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1RZ3MNNAFAMZ
# 1998  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842EL0PGONFNAFAMZ
# 1999  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246EL09XWXBNAFAMZ
#
#                              old_price
# 0     <div class="old">₦ 190,000</div>
# 1                                  NaN
# 2     <div class="old">₦ 127,000</div>
# 3     <div class="old">₦ 238,000</div>
# 4     <div class="old">₦ 150,000</div>
# ...                                ...
# 1995                               NaN
# 1996                               NaN
# 1997                               NaN
# 1998  <div class="old">₦ 195,000</div>
# 1999                               NaN
#
# [2000 rows x 6 columns]

# %%
# replace the NaN values with 0
df['product_rating'] = df['product_rating'].fillna(0)
df['old_price'] = df['old_price'].fillna(0)
df[1:44]
# Out:
#                                          product_name product_price  \
# 1   Hp 15 DW1207NIA Intel Celeron N4020,4GB/500GB ...     ₦ 156,760
# 2   Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 3   Infinix INBook X1 Pro Intel Core I3 256GB SSD ...     ₦ 210,500
# 4   Lenovo INTEL® CELERON® Lenovo Ideapad 4GB RAM ...     ₦ 130,910
# 5   Hp 15 Intel Celeron 4GB RAM 500GB Hard Drive W...     ₦ 164,350
# 6   Hp HP 14-CF2049NIA Laptop (CEL-N4020, 4GB/1TD ...     ₦ 163,030
# 7   Hp 14 Intel Celeron N4020 8GB RAM 1TB HDD Wind...     ₦ 177,800
# 8   Hp Stream 11 Intel Celeron 2GB RAM- 32GB HDD W...      ₦ 96,265
# 9   Multipurpose Foldable Table, Bed Side Table, T...       ₦ 8,030
# 10  Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 11  Classic Macbook Soft Sleeve Case/Bag.Suitable ...       ₦ 5,200
# 12  Hp Stream 14-Intel Celeron N3060 1.6GHz 4GB RA...     ₦ 130,000
# 13  Hp Pavilion 15 Intel Core I3 - 16GB RAM - TOUC...     ₦ 264,740
# 14  Lenovo Intel Celeron N400 4GB RAM 64GB EMMC 11...     ₦ 130,480
# 15  Classic Macbook Soft Sleeve Case/Bag.Suitable ...       ₦ 5,250
# 16  Hp 255 G8 AMD RYZEN 3,1TB HDD, 8GB RAM, Wins 1...     ₦ 209,750
# 17  Lenovo S145-15IGM Intel Celeron -N4000 4GB RAM...     ₦ 145,075
# 18  Hp 15 Touchscreen, Intel Celeron N4020 8GB RAM...     ₦ 187,500
# 19  Lenovo Ideapad  Intel Celeron 1TB HDD 4GB RAM ...     ₦ 135,999
# 20  Hp Stream 11 Intel Celeron D/C  4GB RAM- 32GB ...     ₦ 107,000
# 21  Asus E210MA-GJ068T LAPTOP (CEL-N4020/4GB/128GB...     ₦ 133,580
# 22  Hp Stream 14-Intel Celeron N3060 1.6GHz 4GB RA...     ₦ 145,000
# 23  Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 24  Portable Aluminum 7~15.4 Inch Laptop Stand Als...       ₦ 7,500
# 25  Hp Pavilion 15 - Intel Core I5 - Touchscreen- ...     ₦ 350,390
# 26  Lenovo Ideapad 14inch AMD Quad Core 1TB HDD 8G...     ₦ 189,700
# 27  Hp 15 Touchscreen, Intel Celeron N4020 4GB RAM...     ₦ 177,500
# 28  Multifunctional Laptop Foldable Table,Bed Side...       ₦ 8,580
# 29  Portable 7~15.4 Inch Laptop Stand Also For Tab...       ₦ 6,995
# 30  Hp Stream 11 Intel Celeron D/C  4GB RAM- 32GB ...     ₦ 110,000
# 31  Hp Pavilion 15 Intel Pentium -FingerPrint Read...     ₦ 213,499
# 32  Apple MacBook Pro 14" M1 Pro Chip 16GB RAM, 51...   ₦ 1,235,000
# 33  Hp 15 Intel Celeron N4020 8GB RAM 1TB HDD Wind...     ₦ 178,990
# 34  Lenovo Ideapad 15 - AMD QUAD CORE 1TB HDD 8GB ...     ₦ 186,000
# 35  Hp 15 10th Gen Intel Core I3 12GB RAM,1TB HDD-...     ₦ 261,820
# 36  Lenovo Ideapad  Intel Celeron 1TB HDD 4GB RAM ...     ₦ 135,999
# 37  Lenovo Ideapad  Intel Celeron 1TB HDD 4GB RAM ...     ₦ 135,999
# 38  Hp Stream 11 Pro- Intel Celeron- Education Edi...     ₦ 105,000
# 39  Hp Stream 11 Pro Intel Celeron   4GB RAM- 64GB...     ₦ 105,000
# 40  Hp 15 Intel Core I5 11th Gen  16GB RAM /1TB HD...     ₦ 400,000
# 41  Hp Notebook 14 Intel Core I3 12GB RAM/1TB HDD-...     ₦ 248,998
# 42  Hp 255 G8 AMD RYZEN 3,1TB HDD, 16GB RAM, 15.6"...     ₦ 236,000
# 43  Lenovo Ideapad Intel Core I3 - 8GB RAM -1TB HD...     ₦ 225,000
#
#                                        product_rating  \
# 1   <div class="stars _s">4 out of 5<div class="in...
# 2   <div class="stars _s">3.9 out of 5<div class="...
# 3   <div class="stars _s">4.5 out of 5<div class="...
# 4   <div class="stars _s">4.2 out of 5<div class="...
# 5   <div class="stars _s">4.8 out of 5<div class="...
# 6   <div class="stars _s">4.3 out of 5<div class="...
# 7   <div class="stars _s">5 out of 5<div class="in...
# 8   <div class="stars _s">4.3 out of 5<div class="...
# 9   <div class="stars _s">4.5 out of 5<div class="...
# 10  <div class="stars _s">4.5 out of 5<div class="...
# 11  <div class="stars _s">4.3 out of 5<div class="...
# 12  <div class="stars _s">4.3 out of 5<div class="...
# 13  <div class="stars _s">3.8 out of 5<div class="...
# 14                                                  0
# 15  <div class="stars _s">4.4 out of 5<div class="...
# 16  <div class="stars _s">5 out of 5<div class="in...
# 17  <div class="stars _s">4 out of 5<div class="in...
# 18                                                  0
# 19  <div class="stars _s">3.5 out of 5<div class="...
# 20  <div class="stars _s">3.5 out of 5<div class="...
# 21  <div class="stars _s">3 out of 5<div class="in...
# 22                                                  0
# 23  <div class="stars _s">3.5 out of 5<div class="...
# 24  <div class="stars _s">4.4 out of 5<div class="...
# 25  <div class="stars _s">5 out of 5<div class="in...
# 26  <div class="stars _s">4.2 out of 5<div class="...
# 27                                                  0
# 28  <div class="stars _s">4.6 out of 5<div class="...
# 29                                                  0
# 30  <div class="stars _s">3.7 out of 5<div class="...
# 31  <div class="stars _s">4 out of 5<div class="in...
# 32  <div class="stars _s">5 out of 5<div class="in...
# 33  <div class="stars _s">4.4 out of 5<div class="...
# 34  <div class="stars _s">5 out of 5<div class="in...
# 35  <div class="stars _s">4.3 out of 5<div class="...
# 36  <div class="stars _s">3 out of 5<div class="in...
# 37  <div class="stars _s">4.7 out of 5<div class="...
# 38  <div class="stars _s">3.5 out of 5<div class="...
# 39  <div class="stars _s">3.5 out of 5<div class="...
# 40  <div class="stars _s">4.7 out of 5<div class="...
# 41  <div class="stars _s">4.2 out of 5<div class="...
# 42                                                  0
# 43  <div class="stars _s">5 out of 5<div class="in...
#
#                                       product_img_url          product_SKU  \
# 1   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL2A5NICNAFAMZ
# 2   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1MUH3JNAFAMZ
# 3   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  IN717CL1WDKK4NAFAMZ
# 4   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL2UIZLFNAFAMZ
# 5   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL18FHX4NAFAMZ
# 6   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0HVYEDNAFAMZ
# 7   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL32J3XBNAFAMZ
# 8   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1COA19NAFAMZ
# 9   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD0XVM3ONAFAMZ
# 10  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1DPL7PNAFAMZ
# 11  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779CL1MFGTTNAFAMZ
# 12  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246EL0HIFDQNAFAMZ
# 13  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL26Y7HYNAFAMZ
# 14  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0QKXWNNAFAMZ
# 15  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779CL034AQ9NAFAMZ
# 16  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL23ENTZNAFAMZ
# 17  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0WJ9YFNAFAMZ
# 18  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL28HNO8NAFAMZ
# 19  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL08NB0ZNAFAMZ
# 20  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0WJPFCNAFAMZ
# 21  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  AS650CL1M5LZFNAFAMZ
# 22  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246EL28XYO4NAFAMZ
# 23  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0Q7AE5NAFAMZ
# 24  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD17PY24NAFAMZ
# 25  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0C1KBDNAFAMZ
# 26  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL03YTAVNAFAMZ
# 27  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL24XYG8NAFAMZ
# 28  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD12O14GNAFAMZ
# 29  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD2UDGCONAFAMZ
# 30  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0NZKKSNAFAMZ
# 31  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0WU66NNAFAMZ
# 32  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  AP044CL0EGU5TNAFAMZ
# 33  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL29NAJMNAFAMZ
# 34  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL1XGMMGNAFAMZ
# 35  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL07T01FNAFAMZ
# 36  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0O4YN7NAFAMZ
# 37  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL1ICJ8TNAFAMZ
# 38  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0MIW9XNAFAMZ
# 39  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL2RDAJ4NAFAMZ
# 40  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0XK0IWNAFAMZ
# 41  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0Q5KIDNAFAMZ
# 42  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL32EZQVNAFAMZ
# 43  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0COI17NAFAMZ
#
#                            old_price
# 1                                  0
# 2   <div class="old">₦ 127,000</div>
# 3   <div class="old">₦ 238,000</div>
# 4   <div class="old">₦ 150,000</div>
# 5                                  0
# 6                                  0
# 7   <div class="old">₦ 205,000</div>
# 8   <div class="old">₦ 100,000</div>
# 9     <div class="old">₦ 8,500</div>
# 10  <div class="old">₦ 170,000</div>
# 11    <div class="old">₦ 6,700</div>
# 12                                 0
# 13  <div class="old">₦ 285,000</div>
# 14                                 0
# 15    <div class="old">₦ 6,700</div>
# 16  <div class="old">₦ 238,000</div>
# 17                                 0
# 18  <div class="old">₦ 210,000</div>
# 19  <div class="old">₦ 172,000</div>
# 20  <div class="old">₦ 238,000</div>
# 21                                 0
# 22                                 0
# 23  <div class="old">₦ 145,000</div>
# 24    <div class="old">₦ 9,500</div>
# 25  <div class="old">₦ 473,000</div>
# 26  <div class="old">₦ 203,500</div>
# 27  <div class="old">₦ 195,000</div>
# 28                                 0
# 29   <div class="old">₦ 19,000</div>
# 30  <div class="old">₦ 170,000</div>
# 31  <div class="old">₦ 265,000</div>
# 32                                 0
# 33  <div class="old">₦ 215,000</div>
# 34                                 0
# 35  <div class="old">₦ 299,000</div>
# 36  <div class="old">₦ 172,000</div>
# 37  <div class="old">₦ 190,000</div>
# 38                                 0
# 39                                 0
# 40                                 0
# 41  <div class="old">₦ 290,000</div>
# 42  <div class="old">₦ 270,000</div>
# 43  <div class="old">₦ 258,000</div>

# %%
# Delete empty rows
df.dropna(inplace = True) 
df[1:44]
# Out:
#                                          product_name product_price  \
# 1   Hp 15 DW1207NIA Intel Celeron N4020,4GB/500GB ...     ₦ 156,760
# 2   Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 3   Infinix INBook X1 Pro Intel Core I3 256GB SSD ...     ₦ 210,500
# 4   Lenovo INTEL® CELERON® Lenovo Ideapad 4GB RAM ...     ₦ 130,910
# 5   Hp 15 Intel Celeron 4GB RAM 500GB Hard Drive W...     ₦ 164,350
# 6   Hp HP 14-CF2049NIA Laptop (CEL-N4020, 4GB/1TD ...     ₦ 163,030
# 7   Hp 14 Intel Celeron N4020 8GB RAM 1TB HDD Wind...     ₦ 177,800
# 8   Hp Stream 11 Intel Celeron 2GB RAM- 32GB HDD W...      ₦ 96,265
# 9   Multipurpose Foldable Table, Bed Side Table, T...       ₦ 8,030
# 10  Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 11  Classic Macbook Soft Sleeve Case/Bag.Suitable ...       ₦ 5,200
# 12  Hp Stream 14-Intel Celeron N3060 1.6GHz 4GB RA...     ₦ 130,000
# 13  Hp Pavilion 15 Intel Core I3 - 16GB RAM - TOUC...     ₦ 264,740
# 14  Lenovo Intel Celeron N400 4GB RAM 64GB EMMC 11...     ₦ 130,480
# 15  Classic Macbook Soft Sleeve Case/Bag.Suitable ...       ₦ 5,250
# 16  Hp 255 G8 AMD RYZEN 3,1TB HDD, 8GB RAM, Wins 1...     ₦ 209,750
# 17  Lenovo S145-15IGM Intel Celeron -N4000 4GB RAM...     ₦ 145,075
# 18  Hp 15 Touchscreen, Intel Celeron N4020 8GB RAM...     ₦ 187,500
# 19  Lenovo Ideapad  Intel Celeron 1TB HDD 4GB RAM ...     ₦ 135,999
# 20  Hp Stream 11 Intel Celeron D/C  4GB RAM- 32GB ...     ₦ 107,000
# 21  Asus E210MA-GJ068T LAPTOP (CEL-N4020/4GB/128GB...     ₦ 133,580
# 22  Hp Stream 14-Intel Celeron N3060 1.6GHz 4GB RA...     ₦ 145,000
# 23  Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 24  Portable Aluminum 7~15.4 Inch Laptop Stand Als...       ₦ 7,500
# 25  Hp Pavilion 15 - Intel Core I5 - Touchscreen- ...     ₦ 350,390
# 26  Lenovo Ideapad 14inch AMD Quad Core 1TB HDD 8G...     ₦ 189,700
# 27  Hp 15 Touchscreen, Intel Celeron N4020 4GB RAM...     ₦ 177,500
# 28  Multifunctional Laptop Foldable Table,Bed Side...       ₦ 8,580
# 29  Portable 7~15.4 Inch Laptop Stand Also For Tab...       ₦ 6,995
# 30  Hp Stream 11 Intel Celeron D/C  4GB RAM- 32GB ...     ₦ 110,000
# 31  Hp Pavilion 15 Intel Pentium -FingerPrint Read...     ₦ 213,499
# 32  Apple MacBook Pro 14" M1 Pro Chip 16GB RAM, 51...   ₦ 1,235,000
# 33  Hp 15 Intel Celeron N4020 8GB RAM 1TB HDD Wind...     ₦ 178,990
# 34  Lenovo Ideapad 15 - AMD QUAD CORE 1TB HDD 8GB ...     ₦ 186,000
# 35  Hp 15 10th Gen Intel Core I3 12GB RAM,1TB HDD-...     ₦ 261,820
# 36  Lenovo Ideapad  Intel Celeron 1TB HDD 4GB RAM ...     ₦ 135,999
# 37  Lenovo Ideapad  Intel Celeron 1TB HDD 4GB RAM ...     ₦ 135,999
# 38  Hp Stream 11 Pro- Intel Celeron- Education Edi...     ₦ 105,000
# 39  Hp Stream 11 Pro Intel Celeron   4GB RAM- 64GB...     ₦ 105,000
# 40  Hp 15 Intel Core I5 11th Gen  16GB RAM /1TB HD...     ₦ 400,000
# 41  Hp Notebook 14 Intel Core I3 12GB RAM/1TB HDD-...     ₦ 248,998
# 42  Hp 255 G8 AMD RYZEN 3,1TB HDD, 16GB RAM, 15.6"...     ₦ 236,000
# 43  Lenovo Ideapad Intel Core I3 - 8GB RAM -1TB HD...     ₦ 225,000
#
#                                        product_rating  \
# 1   <div class="stars _s">4 out of 5<div class="in...
# 2   <div class="stars _s">3.9 out of 5<div class="...
# 3   <div class="stars _s">4.5 out of 5<div class="...
# 4   <div class="stars _s">4.2 out of 5<div class="...
# 5   <div class="stars _s">4.8 out of 5<div class="...
# 6   <div class="stars _s">4.3 out of 5<div class="...
# 7   <div class="stars _s">5 out of 5<div class="in...
# 8   <div class="stars _s">4.3 out of 5<div class="...
# 9   <div class="stars _s">4.5 out of 5<div class="...
# 10  <div class="stars _s">4.5 out of 5<div class="...
# 11  <div class="stars _s">4.3 out of 5<div class="...
# 12  <div class="stars _s">4.3 out of 5<div class="...
# 13  <div class="stars _s">3.8 out of 5<div class="...
# 14                                                  0
# 15  <div class="stars _s">4.4 out of 5<div class="...
# 16  <div class="stars _s">5 out of 5<div class="in...
# 17  <div class="stars _s">4 out of 5<div class="in...
# 18                                                  0
# 19  <div class="stars _s">3.5 out of 5<div class="...
# 20  <div class="stars _s">3.5 out of 5<div class="...
# 21  <div class="stars _s">3 out of 5<div class="in...
# 22                                                  0
# 23  <div class="stars _s">3.5 out of 5<div class="...
# 24  <div class="stars _s">4.4 out of 5<div class="...
# 25  <div class="stars _s">5 out of 5<div class="in...
# 26  <div class="stars _s">4.2 out of 5<div class="...
# 27                                                  0
# 28  <div class="stars _s">4.6 out of 5<div class="...
# 29                                                  0
# 30  <div class="stars _s">3.7 out of 5<div class="...
# 31  <div class="stars _s">4 out of 5<div class="in...
# 32  <div class="stars _s">5 out of 5<div class="in...
# 33  <div class="stars _s">4.4 out of 5<div class="...
# 34  <div class="stars _s">5 out of 5<div class="in...
# 35  <div class="stars _s">4.3 out of 5<div class="...
# 36  <div class="stars _s">3 out of 5<div class="in...
# 37  <div class="stars _s">4.7 out of 5<div class="...
# 38  <div class="stars _s">3.5 out of 5<div class="...
# 39  <div class="stars _s">3.5 out of 5<div class="...
# 40  <div class="stars _s">4.7 out of 5<div class="...
# 41  <div class="stars _s">4.2 out of 5<div class="...
# 42                                                  0
# 43  <div class="stars _s">5 out of 5<div class="in...
#
#                                       product_img_url          product_SKU  \
# 1   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL2A5NICNAFAMZ
# 2   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1MUH3JNAFAMZ
# 3   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  IN717CL1WDKK4NAFAMZ
# 4   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL2UIZLFNAFAMZ
# 5   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL18FHX4NAFAMZ
# 6   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0HVYEDNAFAMZ
# 7   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL32J3XBNAFAMZ
# 8   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1COA19NAFAMZ
# 9   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD0XVM3ONAFAMZ
# 10  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1DPL7PNAFAMZ
# 11  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779CL1MFGTTNAFAMZ
# 12  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246EL0HIFDQNAFAMZ
# 13  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL26Y7HYNAFAMZ
# 14  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0QKXWNNAFAMZ
# 15  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779CL034AQ9NAFAMZ
# 16  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL23ENTZNAFAMZ
# 17  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0WJ9YFNAFAMZ
# 18  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL28HNO8NAFAMZ
# 19  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL08NB0ZNAFAMZ
# 20  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0WJPFCNAFAMZ
# 21  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  AS650CL1M5LZFNAFAMZ
# 22  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246EL28XYO4NAFAMZ
# 23  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0Q7AE5NAFAMZ
# 24  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD17PY24NAFAMZ
# 25  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0C1KBDNAFAMZ
# 26  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL03YTAVNAFAMZ
# 27  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL24XYG8NAFAMZ
# 28  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD12O14GNAFAMZ
# 29  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD2UDGCONAFAMZ
# 30  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0NZKKSNAFAMZ
# 31  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0WU66NNAFAMZ
# 32  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  AP044CL0EGU5TNAFAMZ
# 33  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL29NAJMNAFAMZ
# 34  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL1XGMMGNAFAMZ
# 35  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL07T01FNAFAMZ
# 36  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0O4YN7NAFAMZ
# 37  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL1ICJ8TNAFAMZ
# 38  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0MIW9XNAFAMZ
# 39  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL2RDAJ4NAFAMZ
# 40  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0XK0IWNAFAMZ
# 41  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0Q5KIDNAFAMZ
# 42  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL32EZQVNAFAMZ
# 43  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0COI17NAFAMZ
#
#                            old_price
# 1                                  0
# 2   <div class="old">₦ 127,000</div>
# 3   <div class="old">₦ 238,000</div>
# 4   <div class="old">₦ 150,000</div>
# 5                                  0
# 6                                  0
# 7   <div class="old">₦ 205,000</div>
# 8   <div class="old">₦ 100,000</div>
# 9     <div class="old">₦ 8,500</div>
# 10  <div class="old">₦ 170,000</div>
# 11    <div class="old">₦ 6,700</div>
# 12                                 0
# 13  <div class="old">₦ 285,000</div>
# 14                                 0
# 15    <div class="old">₦ 6,700</div>
# 16  <div class="old">₦ 238,000</div>
# 17                                 0
# 18  <div class="old">₦ 210,000</div>
# 19  <div class="old">₦ 172,000</div>
# 20  <div class="old">₦ 238,000</div>
# 21                                 0
# 22                                 0
# 23  <div class="old">₦ 145,000</div>
# 24    <div class="old">₦ 9,500</div>
# 25  <div class="old">₦ 473,000</div>
# 26  <div class="old">₦ 203,500</div>
# 27  <div class="old">₦ 195,000</div>
# 28                                 0
# 29   <div class="old">₦ 19,000</div>
# 30  <div class="old">₦ 170,000</div>
# 31  <div class="old">₦ 265,000</div>
# 32                                 0
# 33  <div class="old">₦ 215,000</div>
# 34                                 0
# 35  <div class="old">₦ 299,000</div>
# 36  <div class="old">₦ 172,000</div>
# 37  <div class="old">₦ 190,000</div>
# 38                                 0
# 39                                 0
# 40                                 0
# 41  <div class="old">₦ 290,000</div>
# 42  <div class="old">₦ 270,000</div>
# 43  <div class="old">₦ 258,000</div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   product_name     2000 non-null   object
#  1   product_price    2000 non-null   object
#  2   product_rating   2000 non-null   object
#  3   product_img_url  2000 non-null   object
#  4   product_SKU      2000 non-null   object
#  5   old_price        2000 non-null   object
# dtypes: object(6)
# memory usage: 93.9+ KB

# %%
df['new_rating'] = df.product_rating.str.slice(22, 26)
df['new_rating2'] = df.new_rating.str.replace('ou', '')

# drop new_rating column
df.drop(['new_rating', 'product_rating'], axis=1, inplace=True)

# rename new_rating2 to produce_rating
df.rename(columns={'new_rating2':'product_rating'}, inplace=True)
df
# Out:
#                                            product_name product_price  \
# 0     Lenovo Ideapad Intel Celeron 1TB HDD 8GB RAM W...     ₦ 169,990
# 1     Hp 15 DW1207NIA Intel Celeron N4020,4GB/500GB ...     ₦ 156,760
# 2     Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 3     Infinix INBook X1 Pro Intel Core I3 256GB SSD ...     ₦ 210,500
# 4     Lenovo INTEL® CELERON® Lenovo Ideapad 4GB RAM ...     ₦ 130,910
# ...                                                 ...           ...
# 1995  DELL Inspiron 3501-7897BLK Core™ I7-1165G7 512...     ₦ 550,000
# 1996  Hp Pavilion 14 X360 11th Gen-Core-i3 16GB/512 ...     ₦ 377,000
# 1997  Hp Pavilion 15 Intel Pentium Quad Core 8GB RAM...     ₦ 220,000
# 1998  Lenovo Ideapad  4GBRAM - 1TB HDD Intel Celeron...     ₦ 138,989
# 1999  Hp Stream 11 Intel Celeron (4GB,32GB SSD+  32G...     ₦ 125,500
#
#                                         product_img_url          product_SKU  \
# 0     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0S218XNAFAMZ
# 1     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL2A5NICNAFAMZ
# 2     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1MUH3JNAFAMZ
# 3     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  IN717CL1WDKK4NAFAMZ
# 4     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL2UIZLFNAFAMZ
# ...                                                 ...                  ...
# 1995  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  DE168CL1VMFPRNAFAMZ
# 1996  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0GE0XVNAFAMZ
# 1997  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1RZ3MNNAFAMZ
# 1998  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842EL0PGONFNAFAMZ
# 1999  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246EL09XWXBNAFAMZ
#
#                              old_price product_rating
# 0     <div class="old">₦ 190,000</div>           4.3
# 1                                    0             4
# 2     <div class="old">₦ 127,000</div>           3.9
# 3     <div class="old">₦ 238,000</div>           4.5
# 4     <div class="old">₦ 150,000</div>           4.2
# ...                                ...            ...
# 1995                                 0            NaN
# 1996                                 0            NaN
# 1997                                 0            NaN
# 1998  <div class="old">₦ 195,000</div>            NaN
# 1999                                 0            NaN
#
# [2000 rows x 6 columns]

# %% [markdown]
# ## WORKING WITH TAGS IN OLD PRICE

# %%
df['old_price'] = df['old_price'].str.replace(r'.*₦', '')
df['old_price'] = df.old_price.str.replace('</div>', '')
df[1375:1377]
# Out:
# C:\Users\trust\AppData\Local\Temp\ipykernel_15956\4042235418.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['old_price'] = df['old_price'].str.replace(r'.*₦', '')
#                                            product_name product_price  \
# 1375  Hp Omen 15 Gaming,Intel Core I7, 16GB RAM, 256...     ₦ 840,000
# 1376  Watch Band Strap For Oppo Watch 2 Stainless Steel       ₦ 3,799
#
#                                         product_img_url          product_SKU  \
# 1375  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL03KJHONAFAMZ
# 1376  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779EA1OJ3LENAFAMZ
#
#      old_price product_rating
# 1375       NaN            NaN
# 1376     7,598            NaN

# %%
df['product_rating'] = df['product_rating'].fillna(0)
df['old_price'] = df['old_price'].fillna(0)

# %%
df.isna().sum()
# Out:
# product_name       0
# product_price      0
# product_img_url    0
# product_SKU        0
# old_price          0
# product_rating     0
# dtype: int64

# %%
df
# Out:
#                                            product_name product_price  \
# 0     Lenovo Ideapad Intel Celeron 1TB HDD 8GB RAM W...     ₦ 169,990
# 1     Hp 15 DW1207NIA Intel Celeron N4020,4GB/500GB ...     ₦ 156,760
# 2     Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 3     Infinix INBook X1 Pro Intel Core I3 256GB SSD ...     ₦ 210,500
# 4     Lenovo INTEL® CELERON® Lenovo Ideapad 4GB RAM ...     ₦ 130,910
# ...                                                 ...           ...
# 1995  DELL Inspiron 3501-7897BLK Core™ I7-1165G7 512...     ₦ 550,000
# 1996  Hp Pavilion 14 X360 11th Gen-Core-i3 16GB/512 ...     ₦ 377,000
# 1997  Hp Pavilion 15 Intel Pentium Quad Core 8GB RAM...     ₦ 220,000
# 1998  Lenovo Ideapad  4GBRAM - 1TB HDD Intel Celeron...     ₦ 138,989
# 1999  Hp Stream 11 Intel Celeron (4GB,32GB SSD+  32G...     ₦ 125,500
#
#                                         product_img_url          product_SKU  \
# 0     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0S218XNAFAMZ
# 1     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL2A5NICNAFAMZ
# 2     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1MUH3JNAFAMZ
# 3     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  IN717CL1WDKK4NAFAMZ
# 4     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL2UIZLFNAFAMZ
# ...                                                 ...                  ...
# 1995  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  DE168CL1VMFPRNAFAMZ
# 1996  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0GE0XVNAFAMZ
# 1997  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1RZ3MNNAFAMZ
# 1998  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842EL0PGONFNAFAMZ
# 1999  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246EL09XWXBNAFAMZ
#
#      old_price product_rating
# 0      190,000           4.3
# 1            0             4
# 2      127,000           3.9
# 3      238,000           4.5
# 4      150,000           4.2
# ...        ...            ...
# 1995         0              0
# 1996         0              0
# 1997         0              0
# 1998   195,000              0
# 1999         0              0
#
# [2000 rows x 6 columns]

# %%
df.drop(df.index[df['old_price'] == 0], inplace=True)

# display the dataframe
df
# Out:
#                                            product_name product_price  \
# 0     Lenovo Ideapad Intel Celeron 1TB HDD 8GB RAM W...     ₦ 169,990
# 2     Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 3     Infinix INBook X1 Pro Intel Core I3 256GB SSD ...     ₦ 210,500
# 4     Lenovo INTEL® CELERON® Lenovo Ideapad 4GB RAM ...     ₦ 130,910
# 7     Hp 14 Intel Celeron N4020 8GB RAM 1TB HDD Wind...     ₦ 177,800
# ...                                                 ...           ...
# 1989  Lenovo Intel Celeron 4GB 64GB 11 Inch With 360...     ₦ 140,000
# 1990  Hp STREAM 11 INTEL CELERON® 4GB RAM 32GB EMMC ...     ₦ 103,999
# 1992  Lenovo IDEAPAD 15 Inch - 10TH GEN- INTEL CORE ...     ₦ 220,000
# 1993  Laptop Fan Cooler Notebook Laptop Gaming Cooli...      ₦ 15,139
# 1998  Lenovo Ideapad  4GBRAM - 1TB HDD Intel Celeron...     ₦ 138,989
#
#                                         product_img_url          product_SKU  \
# 0     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0S218XNAFAMZ
# 2     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1MUH3JNAFAMZ
# 3     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  IN717CL1WDKK4NAFAMZ
# 4     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL2UIZLFNAFAMZ
# 7     https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL32J3XBNAFAMZ
# ...                                                 ...                  ...
# 1989  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842EL028BABNAFAMZ
# 1990  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0IODHFNAFAMZ
# 1992  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL2GIBDANAFAMZ
# 1993  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779CL0GWJGJNAFAMZ
# 1998  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842EL0PGONFNAFAMZ
#
#      old_price product_rating
# 0      190,000           4.3
# 2      127,000           3.9
# 3      238,000           4.5
# 4      150,000           4.2
# 7      205,000             5
# ...        ...            ...
# 1989   145,000              0
# 1990   188,000              0
# 1992   240,000              0
# 1993    22,709              0
# 1998   195,000              0
#
# [1247 rows x 6 columns]

# %%
df.old_price.isnull().sum()
# Out:
# 0

# %%
df.to_csv('products master.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Slicing through and converting to csv

# %%
import pandas as pd
df = pd.read_csv('products master.csv')

# %%
df = df[0:30]
df
# Out:
#                                          product_name product_price  \
# 0   Lenovo Ideapad Intel Celeron 1TB HDD 8GB RAM W...     ₦ 169,990
# 1   Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 2   Infinix INBook X1 Pro Intel Core I3 256GB SSD ...     ₦ 210,500
# 3   Lenovo INTEL® CELERON® Lenovo Ideapad 4GB RAM ...     ₦ 130,910
# 4   Hp 14 Intel Celeron N4020 8GB RAM 1TB HDD Wind...     ₦ 177,800
# 5   Hp Stream 11 Intel Celeron 2GB RAM- 32GB HDD W...      ₦ 96,265
# 6   Multipurpose Foldable Table, Bed Side Table, T...       ₦ 8,030
# 7   Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 8   Classic Macbook Soft Sleeve Case/Bag.Suitable ...       ₦ 5,200
# 9   Hp Pavilion 15 Intel Core I3 - 16GB RAM - TOUC...     ₦ 264,740
# 10  Classic Macbook Soft Sleeve Case/Bag.Suitable ...       ₦ 5,250
# 11  Hp 255 G8 AMD RYZEN 3,1TB HDD, 8GB RAM, Wins 1...     ₦ 209,750
# 12  Hp 15 Touchscreen, Intel Celeron N4020 8GB RAM...     ₦ 187,500
# 13  Lenovo Ideapad  Intel Celeron 1TB HDD 4GB RAM ...     ₦ 135,999
# 14  Hp Stream 11 Intel Celeron D/C  4GB RAM- 32GB ...     ₦ 107,000
# 15  Hp Stream 11 Intel Celeron D/C  4GB RAM- 64GB ...     ₦ 103,999
# 16  Portable Aluminum 7~15.4 Inch Laptop Stand Als...       ₦ 7,500
# 17  Hp Pavilion 15 - Intel Core I5 - Touchscreen- ...     ₦ 350,390
# 18  Lenovo Ideapad 14inch AMD Quad Core 1TB HDD 8G...     ₦ 189,700
# 19  Hp 15 Touchscreen, Intel Celeron N4020 4GB RAM...     ₦ 177,500
# 20  Portable 7~15.4 Inch Laptop Stand Also For Tab...       ₦ 6,995
# 21  Hp Stream 11 Intel Celeron D/C  4GB RAM- 32GB ...     ₦ 110,000
# 22  Hp Pavilion 15 Intel Pentium -FingerPrint Read...     ₦ 213,499
# 23  Hp 15 Intel Celeron N4020 8GB RAM 1TB HDD Wind...     ₦ 178,990
# 24  Hp 15 10th Gen Intel Core I3 12GB RAM,1TB HDD-...     ₦ 261,820
# 25  Lenovo Ideapad  Intel Celeron 1TB HDD 4GB RAM ...     ₦ 135,999
# 26  Lenovo Ideapad  Intel Celeron 1TB HDD 4GB RAM ...     ₦ 135,999
# 27  Hp Notebook 14 Intel Core I3 12GB RAM/1TB HDD-...     ₦ 248,998
# 28  Hp 255 G8 AMD RYZEN 3,1TB HDD, 16GB RAM, 15.6"...     ₦ 236,000
# 29  Lenovo Ideapad Intel Core I3 - 8GB RAM -1TB HD...     ₦ 225,000
#
#                                       product_img_url          product_SKU  \
# 0   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0S218XNAFAMZ
# 1   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1MUH3JNAFAMZ
# 2   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  IN717CL1WDKK4NAFAMZ
# 3   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL2UIZLFNAFAMZ
# 4   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL32J3XBNAFAMZ
# 5   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1COA19NAFAMZ
# 6   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD0XVM3ONAFAMZ
# 7   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL1DPL7PNAFAMZ
# 8   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779CL1MFGTTNAFAMZ
# 9   https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL26Y7HYNAFAMZ
# 10  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779CL034AQ9NAFAMZ
# 11  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL23ENTZNAFAMZ
# 12  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL28HNO8NAFAMZ
# 13  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL08NB0ZNAFAMZ
# 14  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0WJPFCNAFAMZ
# 15  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0Q7AE5NAFAMZ
# 16  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD17PY24NAFAMZ
# 17  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0C1KBDNAFAMZ
# 18  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL03YTAVNAFAMZ
# 19  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL24XYG8NAFAMZ
# 20  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  GE779FD2UDGCONAFAMZ
# 21  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0NZKKSNAFAMZ
# 22  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0WU66NNAFAMZ
# 23  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL29NAJMNAFAMZ
# 24  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL07T01FNAFAMZ
# 25  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0O4YN7NAFAMZ
# 26  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL1ICJ8TNAFAMZ
# 27  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL0Q5KIDNAFAMZ
# 28  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  HP246CL32EZQVNAFAMZ
# 29  https://ng.jumia.is/unsafe/fit-in/300x300/filt...  LE842CL0COI17NAFAMZ
#
#    old_price  product_rating
# 0    190,000             4.3
# 1    127,000             3.9
# 2    238,000             4.5
# 3    150,000             4.2
# 4    205,000             5.0
# 5    100,000             4.3
# 6      8,500             4.5
# 7    170,000             4.5
# 8      6,700             4.3
# 9    285,000             3.8
# 10     6,700             4.4
# 11   238,000             5.0
# 12   210,000             0.0
# 13   172,000             3.5
# 14   238,000             3.5
# 15   145,000             3.5
# 16     9,500             4.4
# 17   473,000             5.0
# 18   203,500             4.2
# 19   195,000             0.0
# 20    19,000             0.0
# 21   170,000             3.7
# 22   265,000             4.0
# 23   215,000             4.4
# 24   299,000             4.3
# 25   172,000             3.0
# 26   190,000             4.7
# 27   290,000             4.2
# 28   270,000             0.0
# 29   258,000             5.0

# %%
df.to_csv('todays work.csv', index=False, encoding='utf-8')

# %% [markdown]
# # TO FIND TREASURE HUNT ITEMS WITH SELENIUM
#
# First, specify where to find the item (webpage)
#
# Second, code to search the webpage for the specified item

# %%
# create a dict file with text and href(links of text)
## dict = {'supermarket':'https://www.jumia.com.ng/groceries/', 'health & beauty':'https://www.jumia.com.ng/health-beauty/', 
##        'home & office':'https://www.jumia.com.ng/home-office/',   'phones & tablets':'https://www.jumia.com.ng/phones-tablets/',   
##        'computing':f'https://www.jumia.com.ng/computing/?page={page}#catalog-listing',   'electronics':'https://www.jumia.com.ng/electronics/',  
##        'fashion':'https://www.jumia.com.ng/category-fashion-by-jumia/', 'baby products':'https://www.jumia.com.ng/baby-products/',   
##        'gaming':'https://www.jumia.com.ng/video-games/',  'sporting goods':'https://www.jumia.com.ng/sporting-goods/',  
##        'automobile':'https://www.jumia.com.ng/automobile/'}



        ## input_text = str((input('Where to find the item? ')))


        # Get values of the inputed key in list of dictionaries
        ## link = (dict[input_text])
        ## print(link)



        # ChromeDriver code
        # path = './msedgedriver.exe'

        # open the browser
        # dr = wb.Edge(executable_path=path)

        # load the webpage
        # dr.maximize_window()
